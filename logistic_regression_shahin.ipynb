# %% [markdown]
# <a href="https://colab.research.google.com/github/jitinmaurya/Email-Spam-Filtering-System-/blob/logistic_regression_shahin/logistic_regression_shahin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
token = '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'
# !git clone https://{token}@github.com/jitinmaurya/Email-Spam-Filtering-System-.git
# %cd Email-Spam-Filtering-System-
# Out:
# Cloning into 'Email-Spam-Filtering-System-'...
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/jitinmaurya/Email-Spam-Filtering-System-.git/': The requested URL returned error: 403
# [Errno 2] No such file or directory: 'Email-Spam-Filtering-System-'
# /content
